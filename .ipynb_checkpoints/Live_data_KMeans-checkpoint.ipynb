# %% [markdown]
# ## 📜 Proprietary & All Rights Reserved
#
# © 2025 Sweety Seelam.
# This work is proprietary and protected by copyright.
# No part of this project, app, code, or analysis may be copied, reproduced, distributed, or used for any purpose—commercial or otherwise—without explicit written permission from the author.
#
# ------
# ------

# %% [markdown]
# # 📊 Live Social Media Post Segmentation with K-Means Clustering
# ### Uncovering Patterns in User Engagement to Optimize Content Strategy

# %% [markdown]
# ## 🏢 Business Problem
#
# Modern brands invest heavily in social media, but most struggle to identify *which types of posts drive meaningful engagement* and why. Raw metrics alone (likes, shares, reactions) don’t reveal *actionable segments* among your content types.
#
# ***How can we automatically segment posts to uncover engagement patterns and optimize content for maximum reach and brand growth?***

# %% [markdown]
# ## 🎯 Objective
#
# - *Cluster social media posts* based on engagement metrics (likes, shares, reactions, etc.) to discover high-engagement segments.
# - Provide actionable, data-driven recommendations for content strategy.
# - Demonstrate unsupervised learning (K-Means) on real engagement data.

# %% [markdown]
# ## 🗃️ Dataset Information
#
# - **Source**: [UCI Machine Learning Repository — Facebook Live Posts Dataset](https://archive.ics.uci.edu/ml/datasets/Facebook+Live+Sellers+in+Thailand)
# - **File Used**: `Live.dataset_K-means.csv`
# - **Shape**: 7,050 rows × 16 columns
#
# **Features Used**
# - `status_type` *(video/photo/link/status)*
# - `num_reactions`, `num_comments`, `num_shares`, `num_likes`, `num_loves`, `num_wows`, `num_hahas`, `num_sads`, `num_angrys`
# - Timestamps, IDs, and unnamed columns dropped in preprocessing
#
# *See [Dataset UCI Link](https://archive.ics.uci.edu/ml/datasets/Facebook+Live+Sellers+in+Thailand) for full documentation.*
#
# ---

# %% [markdown]
# ## Step 1: Importing libraries & Data Loading

# %%
# Import required libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns


# Display plots inline
# %matplotlib inline

# %%
# load the dataset
data = pd.read_csv(r"C:\Users\sweet\Desktop\DataScience\Github projects\Deployment files\LiveData_K-Means\Live.dataset_K-means.csv")

# %%
# Overview of the first 5 rows of the dataset
data.head()
# Out:
#                           status_id status_type status_published  \
# 0  246675545449582_1649696485147474       video   4/22/2018 6:00
# 1  246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2  246675545449582_1648730588577397       video   4/21/2018 6:17
# 3  246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4  246675545449582_1645700502213739       photo   4/18/2018 3:22
#
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0            529           512         262        432         92         3
# 1            150             0           0        150          0         0
# 2            227           236          57        204         21         1
# 3            111             0           0        111          0         0
# 4            213             0           0        204          9         0
#
#    num_hahas  num_sads  num_angrys  Column1  Column2  Column3  Column4
# ...

# %% [markdown]
# ## 📋 Step 2: Data Overview & Exploration

# %%
# Data information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_id         7050 non-null   object
#  1   status_type       7050 non-null   object
#  2   status_published  7050 non-null   object
#  3   num_reactions     7050 non-null   int64
#  4   num_comments      7050 non-null   int64
#  5   num_shares        7050 non-null   int64
#  6   num_likes         7050 non-null   int64
#  7   num_loves         7050 non-null   int64
#  8   num_wows          7050 non-null   int64
#  9   num_hahas         7050 non-null   int64
#  10  num_sads          7050 non-null   int64
#  11  num_angrys        7050 non-null   int64
#  12  Column1           0 non-null      float64
#  13  Column2           0 non-null      float64
#  14  Column3           0 non-null      float64
#  15  Column4           0 non-null      float64
# ...

# %%
# Statistical summary
data.describe()
# Out:
#        num_reactions  num_comments   num_shares    num_likes    num_loves  \
# count    7050.000000   7050.000000  7050.000000  7050.000000  7050.000000
# mean      230.117163    224.356028    40.022553   215.043121    12.728652
# std       462.625309    889.636820   131.599965   449.472357    39.972930
# min         0.000000      0.000000     0.000000     0.000000     0.000000
# 25%        17.000000      0.000000     0.000000    17.000000     0.000000
# 50%        59.500000      4.000000     0.000000    58.000000     0.000000
# 75%       219.000000     23.000000     4.000000   184.750000     3.000000
# max      4710.000000  20990.000000  3424.000000  4710.000000   657.000000
#
#           num_wows    num_hahas     num_sads   num_angrys  Column1  Column2  \
# count  7050.000000  7050.000000  7050.000000  7050.000000      0.0      0.0
# mean      1.289362     0.696454     0.243688     0.113191      NaN      NaN
# ...

# %%
# Dataset Shape and info
data.shape
# Out:
# (7050, 16)

# %%
#Check for the unique values
data['status_type'].unique()
# Out:
# array(['video', 'photo', 'link', 'status'], dtype=object)

# %%
# Check nulls and unique values
data.isnull().sum()
# Out:
# status_id              0
# status_type            0
# status_published       0
# num_reactions          0
# num_comments           0
# num_shares             0
# num_likes              0
# num_loves              0
# num_wows               0
# num_hahas              0
# num_sads               0
# num_angrys             0
# Column1             7050
# Column2             7050
# Column3             7050
# Column4             7050
# dtype: int64

# %%
data.columns
# Out:
# Index(['status_id', 'status_type', 'status_published', 'num_reactions',
#        'num_comments', 'num_shares', 'num_likes', 'num_loves', 'num_wows',
#        'num_hahas', 'num_sads', 'num_angrys', 'Column1', 'Column2', 'Column3',
#        'Column4'],
#       dtype='object')

# %% [markdown]
# ## 🧹 Data Cleaning & Preprocessing
#
# - Remove unused columns (`Column1-4`, `status_id`, `status_published`)
# - Encode categorical variables
# - Feature scale for KMeans

# %%
# Drop unused columns (all-NaN columns, ID and timestamp columns)
data.drop(['Column1','Column2','Column3','Column4'], axis=1, inplace=True)

# %%
data.head(7050)
# Out:
#                               status_id status_type status_published  \
# 0      246675545449582_1649696485147474       video   4/22/2018 6:00
# 1      246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2      246675545449582_1648730588577397       video   4/21/2018 6:17
# 3      246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4      246675545449582_1645700502213739       photo   4/18/2018 3:22
# ...                                 ...         ...              ...
# 7045  1050855161656896_1061863470556065       photo   9/24/2016 2:58
# 7046  1050855161656896_1061334757275603       photo  9/23/2016 11:19
# 7047  1050855161656896_1060126464063099       photo  9/21/2016 23:03
# 7048  1050855161656896_1058663487542730       photo   9/20/2016 0:43
# 7049  1050855161656896_1050858841656528       photo  9/10/2016 10:30
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# ...

# %%
len(data['status_id'].unique())
# Out:
# 6997

# %%
len(data['status_published'].unique())
# Out:
# 6913

# %%
len(data['status_type'].unique())
# Out:
# 4

# %%
# Drop unnecessary columns of the dataset 
data.drop(['status_id','status_published'], axis=1, inplace=True)

# %%
data.head(7050)
# Out:
#      status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0          video            529           512         262        432
# 1          photo            150             0           0        150
# 2          video            227           236          57        204
# 3          photo            111             0           0        111
# 4          photo            213             0           0        204
# ...          ...            ...           ...         ...        ...
# 7045       photo             89             0           0         89
# 7046       photo             16             0           0         14
# 7047       photo              2             0           0          1
# 7048       photo            351            12          22        349
# 7049       photo             17             0           0         17
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0            92         3          1         1           0
# ...

# %%
df= data
df.head()
# Out:
#   status_type  num_reactions  num_comments  num_shares  num_likes  num_loves  \
# 0       video            529           512         262        432         92
# 1       photo            150             0           0        150          0
# 2       video            227           236          57        204         21
# 3       photo            111             0           0        111          0
# 4       photo            213             0           0        204          9
#
#    num_wows  num_hahas  num_sads  num_angrys
# 0         3          1         1           0
# 1         0          0         0           0
# 2         1          1         0           0
# 3         0          0         0           0
# 4         0          0         0           0

# %%
# Assign the variables for the independent and dependent variables
X = df
y = df['status_type']

# %%
print(X.head())
# Out:
#   status_type  num_reactions  num_comments  num_shares  num_likes  num_loves  \
# 0       video            529           512         262        432         92
# 1       photo            150             0           0        150          0
# 2       video            227           236          57        204         21
# 3       photo            111             0           0        111          0
# 4       photo            213             0           0        204          9
#
#    num_wows  num_hahas  num_sads  num_angrys
# 0         3          1         1           0
# 1         0          0         0           0
# 2         1          1         0           0
# 3         0          0         0           0
# 4         0          0         0           0

# %%
print(y.head())
# Out:
# 0    video
# 1    photo
# 2    video
# 3    photo
# 4    photo
# Name: status_type, dtype: object

# %%
# Encode the categorical variables
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X['status_type']= le.fit_transform(X['status_type'])
y = le.transform(y)

# %%
X.head()
# Out:
#    status_type  num_reactions  num_comments  num_shares  num_likes  num_loves  \
# 0            3            529           512         262        432         92
# 1            1            150             0           0        150          0
# 2            3            227           236          57        204         21
# 3            1            111             0           0        111          0
# 4            1            213             0           0        204          9
#
#    num_wows  num_hahas  num_sads  num_angrys
# 0         3          1         1           0
# 1         0          0         0           0
# 2         1          1         0           0
# 3         0          0         0           0
# 4         0          0         0           0

# %%
y
# Out:
# array([3, 1, 3, ..., 1, 1, 1])

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status_type    7050 non-null   int32
#  1   num_reactions  7050 non-null   int64
#  2   num_comments   7050 non-null   int64
#  3   num_shares     7050 non-null   int64
#  4   num_likes      7050 non-null   int64
#  5   num_loves      7050 non-null   int64
#  6   num_wows       7050 non-null   int64
#  7   num_hahas      7050 non-null   int64
#  8   num_sads       7050 non-null   int64
#  9   num_angrys     7050 non-null   int64
# dtypes: int32(1), int64(9)
# memory usage: 523.4 KB

# %%
cols = X.columns

# %%
# Feature Scaling (Standardizing the dataset)
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
X = mms.fit_transform(X)

# %%
X = pd.DataFrame(X, columns=[cols])

# %%
X.head()
# Out:
#   status_type num_reactions num_comments num_shares num_likes num_loves  \
# 0    1.000000      0.112314     0.024393   0.076519  0.091720  0.140030
# 1    0.333333      0.031847     0.000000   0.000000  0.031847  0.000000
# 2    1.000000      0.048195     0.011243   0.016647  0.043312  0.031963
# 3    0.333333      0.023567     0.000000   0.000000  0.023567  0.000000
# 4    0.333333      0.045223     0.000000   0.000000  0.043312  0.013699
#
#    num_wows num_hahas  num_sads num_angrys
# 0  0.010791  0.006369  0.019608        0.0
# 1  0.000000  0.000000  0.000000        0.0
# 2  0.003597  0.006369  0.000000        0.0
# 3  0.000000  0.000000  0.000000        0.0
# 4  0.000000  0.000000  0.000000        0.0

# %% [markdown]
# ### KMeans Clustering & Elbow Method

# %%
# KMeans Clustering

# Training the Model
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[9.54921576e-01, 6.46330441e-02, 2.67028654e-02, 2.93171709e-02,
#         5.71231462e-02, 4.71007076e-02, 8.18581889e-03, 9.65207685e-03,
#         8.04219428e-03, 7.19501847e-03],
#        [3.28506857e-01, 3.90710874e-02, 7.54854864e-04, 7.53667113e-04,
#         3.85438884e-02, 2.17448568e-03, 2.43721364e-03, 1.20039760e-03,
#         2.75348016e-03, 1.45313276e-03]])

# %%
kmeans.inertia_
# Out:
# 237.7572640441955

# %%
labels = kmeans.labels_
correct_labels = sum(y == labels)
print("Result: %d out of %d samples are correctly labeled."%
     (correct_labels,y.size))
# Out:
# Result: 4288 out of 7050 samples are correctly labeled.

# %%
print('Accuracy Score: {0:0.2f}'.format(correct_labels/float(y.size)))
# Out:
# Accuracy Score: 0.61

# %%
# Find optimal clusters using Elbow method

from sklearn.cluster import KMeans
cs=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=10,random_state=0)
    kmeans.fit(X)
    cs.append(kmeans.inertia_)
plt.plot(range(1,11),cs)
plt.title('The Elbow point')
plt.xlabel('Number of clusters')
plt.ylabel('cs')
plt.show()

# %% [markdown]
# ### Final KMeans Fit, Label Alignment & Evaluation

# %%
kmeans = KMeans(n_clusters=3,random_state=0)
kmeans.fit(X)
labels=kmeans.labels_
correct_labels=sum(y==labels)
print("Result: %d out of %d are labeled correctly."%
      (correct_labels,y.size))
print('Accuracy score: {0:0.2f}'. format(correct_labels/float(y.size)))
# Out:
# Result: 4066 out of 7050 are labeled correctly.
# Accuracy score: 0.58

# %%
kmeans=KMeans(n_clusters=4,random_state=0)
kmeans.fit(X)
labels=kmeans.labels_
correct_labels=sum(y==labels)
print("Result: %d out of %d are correctly labeled."%
     (correct_labels,y.size))
print('Accuracy score: {0:0.2f}'.format(correct_labels/float(y.size)))
# Out:
# Result: 4112 out of 7050 are correctly labeled.
# Accuracy score: 0.58

# %%
from scipy.stats import mode

# Fit K-Means
kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(X)
labels = kmeans.labels_

# Relabel clusters to match true labels
new_labels = np.zeros_like(labels)
for i in range(4):  # Assuming 4 clusters
    mask = (labels == i)
    new_labels[mask] = mode(y[mask])[0]

# Compute accuracy
correct_labels = sum(y == new_labels)
accuracy = correct_labels / y.size

print(f"Result: {correct_labels} out of {y.size} are correctly labeled.")
print(f'Accuracy score: {accuracy:.2f}')
# Out:
# Result: 6920 out of 7050 are correctly labeled.
# Accuracy score: 0.98

# %% [markdown]
# # Conclusion

# %% [markdown]
# #Model Accuracy & Labeling Performance
# 94% Accuracy Score (6622 out of 7050 correctly labeled):
# The model performed exceptionally well when k=4, achieving a high clustering accuracy of 0.94 (94%).
# This indicates that the dataset is naturally suited for four distinct groups.
#
# #Optimal Number of Clusters (Elbow Method)
# The Elbow Point graph initially showed a steep decline in inertia up to k=2, but performance improved significantly at k=4.
# k=4 was the optimal choice, leading to well-defined and meaningful clusters.
# Choosing fewer clusters (e.g., k=2) resulted in poor accuracy and weak cluster separation.
#
# #Model Performance Insights
# Poor performance with k=2 suggests that the dataset had more than two meaningful groups.
# k=4 provided the best structure, meaning the model successfully identified four well-separated groups.
# The high accuracy confirms that the dataset features support this cluster distribution.
#
# #Potential Improvements
# Feature Engineering: Exploring additional features could further refine clustering.
#
# => The best-performing model used k=4, achieving 94% accuracy.
# => This suggests the dataset inherently follows a four-group structure, which K-Means successfully identified.
